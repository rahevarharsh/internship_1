# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
Iris_data=pd.read_csv('Iris.csv')

# %%
Iris_data.shape
# Out:
# (150, 6)

# %%
Iris_data.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
Iris_data['Species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-versicolor    50
# Iris-virginica     50
# Name: Species, dtype: int64

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier()

x = Iris_data.iloc[:,:-1];
y = Iris_data.iloc[:,-1];

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2)

clf.fit(x_train,y_train)
y_predict = clf.predict(x_test)
from sklearn.metrics import confusion_matrix,accuracy_score
print('confusion_matrix :',confusion_matrix(y_test,y_predict)) 
import seaborn as sns
print('accuracy_score : ', accuracy_score(y_test,y_predict))
con_matrix = confusion_matrix(y_test,y_predict)
# sns.heatmap(con_matrixm,annot=True)
# Out:
# confusion_matrix : [[ 7  0  0]
#  [ 0 11  0]
#  [ 0  0 12]]
# accuracy_score :  1.0

# %%
sns.heatmap(con_matrix,annot=True)
# Out:
# <AxesSubplot:>

# %%
fig,ax = plt.subplots(ncols= 2,nrows=2,figsize=(12,5))
ax[0,0].scatter(x.iloc[:,1],y);
# ax[0,0].xlabel('SepalLengthCm')
ax[0,1].scatter(x.iloc[:,2],y)
# ax[0,1].xlabel('SepalWidthCm')
ax[1,0].scatter(x.iloc[:,3],y);
# ax[1,0].xlabel('PetalLengthCm')
# ax[1,1].scatter(x.iloc[:,3],y);
